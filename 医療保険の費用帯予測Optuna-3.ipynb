# %%
import pandas as pd
train = pd.read_csv("train.csv",index_col=0)
test = pd.read_csv("test.csv",index_col=0)
sample_submit = pd.read_csv("sample_submit.csv",index_col=0,header=None)

# %%
train.head()
# Out:
#     age     sex        bmi  children smoker     region  charges
# id
# 0    26    male  32.665465         3     no  southeast        0
# 1    41    male  29.798725         1     no  southwest        0
# 2    28    male  32.722029         0    yes  northwest        1
# 3    20  female  38.429831         2     no  southeast        0
# 4    45  female  29.641854         1     no  northwest        0

# %%
test.head()
# Out:
#     age     sex        bmi  children smoker     region
# id
# 13   19    male  24.365178         1     no  northeast
# 23   59    male  33.997763         0    yes  northeast
# 27   42  female  29.283450         0     no  southwest
# 28   30    male  24.903725         1     no  northwest
# 29   41  female  29.644536         0     no  southwest

# %%
print(train.shape)
print(test.shape)
# Out:
# (1600, 7)
# (400, 6)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1600 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1600 non-null   int64
#  1   sex       1600 non-null   object
#  2   bmi       1600 non-null   float64
#  3   children  1600 non-null   int64
#  4   smoker    1600 non-null   object
#  5   region    1600 non-null   object
#  6   charges   1600 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 100.0+ KB

# %%
train['charges'].value_counts()
# Out:
# 0    1256
# 1     198
# 2     146
# Name: charges, dtype: int64

# %%
train.describe()
# Out:
#                age          bmi     children      charges
# count  1600.000000  1600.000000  1600.000000  1600.000000
# mean     38.985000    32.424376     1.014375     0.306250
# std      13.555012     5.766915     1.259031     0.628656
# min      18.000000    20.627626     0.000000     0.000000
# 25%      27.000000    28.634267     0.000000     0.000000
# 50%      40.000000    32.268786     1.000000     0.000000
# 75%      50.000000    37.069581     2.000000     0.000000
# max      64.000000    47.290644     5.000000     2.000000

# %%
train[['sex','charges']].groupby(['sex']).mean()
# Out:
#          charges
# sex
# female  0.227931
# male    0.376932

# %%
train[['smoker','charges']].groupby(['smoker']).mean()
# Out:
#          charges
# smoker
# no      0.070579
# yes     1.182891

# %%
train[['region','charges']].groupby(['region']).mean()
# Out:
#             charges
# region
# northeast  0.277778
# northwest  0.230769
# southeast  0.465686
# southwest  0.245333

# %%
data = pd.concat([train,test], sort=False)

# %%
data['sex'].replace(['male', 'female'], [0, 1], inplace=True)
data['smoker'].replace(['no', 'yes'], [0, 1], inplace=True)
data['region'] = data['region'].map({'northeast': 0, 'northwest': 1, 'southeast': 2, 'southwest': 3}).astype(int)

# %%
data.head(10)
# Out:
#     age  sex        bmi  children  smoker  region  charges
# id
# 0    26    0  32.665465         3       0       2      0.0
# 1    41    0  29.798725         1       0       3      0.0
# 2    28    0  32.722029         0       1       1      1.0
# 3    20    1  38.429831         2       0       2      0.0
# 4    45    1  29.641854         1       0       1      0.0
# 5    20    0  37.785937         2       1       2      1.0
# 6    37    0  43.393374         2       0       0      0.0
# 7    41    1  32.280407         1       0       0      0.0
# 8    40    0  28.865828         1       0       0      0.0
# 9    54    1  33.870887         2       0       0      0.0

# %%
data.shape
# Out:
# (2000, 7)

# %%
data.reset_index(drop=True, inplace=True)
train = data.loc[:(len(train)-1)]
test = data.loc[len(train):]

# %%
y_train = train['charges']
X_train = train.drop('charges', axis=1)
X_test = test.drop('charges', axis=1)

# %%
X_train.shape
# Out:
# (1600, 6)

# %%
X_test.shape
# Out:
# (400, 6)

# %%
from sklearn.model_selection import train_test_split


X_train, X_valid, y_train, y_valid = \
    train_test_split(X_train, y_train, test_size=0.3,
                                 random_state=0, stratify=y_train)

# %%
from sklearn.metrics import log_loss
import lightgbm as lgb
import numpy as np
import optuna
import tensorflow as tf

categorical_features = ['sex', 'smoker', 'region']

def objective(trial):
    params = {
        'objective': 'multiclass',
        'verbose': -1,
        'num_class': 3,
        'max_bin' : trial.suggest_int('max_bin',255,500),
        'learning_rate' : 0.05,
        'num_leaves' : trial.suggest_int('num_leaves',32,128),
        'metric' : 'multi_logloss',
        'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
        'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 100),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100)
    }
    
    lgb_train = lgb.Dataset(X_train, y_train, categorical_feature=categorical_features)
    lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train, categorical_feature=categorical_features)
    
    model = lgb.train(params,lgb_train,
                      valid_sets=[lgb_train, lgb_eval],
                      verbose_eval=10,
                      num_boost_round=1000,
                      early_stopping_rounds=10)
    y_pred_valid = model.predict(X_valid, num_iteration=model.best_iteration)
    score = log_loss(y_valid,y_pred_valid)
    return score

# %%
study = optuna.create_study(sampler=optuna.samplers.RandomSampler(seed=0))
study.optimize(objective,n_trials=40)
# Out:
# [I 2023-06-19 21:52:26,239] A new study created in memory with name: no-name-5fc864f7-4068-4643-80cb-dd58f2dfcd10
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:26,294] Trial 0 finished with value: 0.38348145448218673 and parameters: {'max_bin': 390, 'num_leaves': 101, 'lambda_l1': 0.0026599310838681858, 'lambda_l2': 0.0008015832747965142, 'feature_fraction': 0.6541928796033428, 'bagging_fraction': 0.7875364678399936, 'bagging_freq': 44, 'min_child_samples': 90}. Best is trial 0 with value: 0.38348145448218673.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:26,373] Trial 1 finished with value: 0.4033856395047986 and parameters: {'max_bin': 492, 'num_leaves': 69, 'lambda_l1': 0.13351354975517513, 'lambda_l2': 0.0005755118598534656, 'feature_fraction': 0.7408267366563595, 'bagging_fraction': 0.9553579829755966, 'bagging_freq': 8, 'min_child_samples': 13}. Best is trial 0 with value: 0.38348145448218673.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:26,426] Trial 2 finished with value: 0.3859421113219809 and parameters: {'max_bin': 259, 'num_leaves': 112, 'lambda_l1': 0.10078844818976519, 'lambda_l2': 0.6762532016190338, 'feature_fraction': 0.9871710053396584, 'bagging_fraction': 0.8794951385300341, 'bagging_freq': 47, 'min_child_samples': 79}. Best is trial 0 with value: 0.38348145448218673.
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.490049	valid_1's multi_logloss: 0.50784
# [20]	training's multi_logloss: 0.425426	valid_1's multi_logloss: 0.448819
# [30]	training's multi_logloss: 0.379504	valid_1's multi_logloss: 0.412643
# [40]	training's multi_logloss: 0.356326	valid_1's multi_logloss: 0.398345
# [50]	training's multi_logloss: 0.339328	valid_1's multi_logloss: 0.390235
# [60]	training's multi_logloss: 0.327231	valid_1's multi_logloss: 0.386616
# [70]	training's multi_logloss: 0.317327	valid_1's multi_logloss: 0.384243
# [80]	training's multi_logloss: 0.308475	valid_1's multi_logloss: 0.383741
# Early stopping, best iteration is:
# [72]	training's multi_logloss: 0.315772	valid_1's multi_logloss: 0.383481
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.436274	valid_1's multi_logloss: 0.501209
# [20]	training's multi_logloss: 0.341583	valid_1's multi_logloss: 0.446205
# [30]	training's multi_logloss: 0.273131	valid_1's multi_logloss: 0.413379
# [40]	training's multi_logloss: 0.229172	valid_1's multi_logloss: 0.405815
# [50]	training's multi_logloss: 0.194194	valid_1's multi_logloss: 0.405516
# Early stopping, best iteration is:
# [45]	training's multi_logloss: 0.211131	valid_1's multi_logloss: 0.403386
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.453245	valid_1's multi_logloss: 0.475933
# [20]	training's multi_logloss: 0.389961	valid_1's multi_logloss: 0.422631
# [30]	training's multi_logloss: 0.357689	valid_1's multi_logloss: 0.40241
# [40]	training's multi_logloss: 0.336511	valid_1's multi_logloss: 0.391195
# [50]	training's multi_logloss: 0.317622	valid_1's multi_logloss: 0.387599
# [60]	training's multi_logloss: 0.303998	valid_1's multi_logloss: 0.38607
# [70]	training's multi_logloss: 0.294307	valid_1's multi_logloss: 0.387233
# Early stopping, best iteration is:
# [63]	training's multi_logloss: 0.300786	valid_1's multi_logloss: 0.385942
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:26,485] Trial 3 finished with value: 0.38845242585348544 and parameters: {'max_bin': 284, 'num_leaves': 94, 'lambda_l1': 1.9506510537765813e-07, 'lambda_l2': 3.177022228527139, 'feature_fraction': 0.7131089930500429, 'bagging_fraction': 0.6487971639943142, 'bagging_freq': 27, 'min_child_samples': 79}. Best is trial 0 with value: 0.38348145448218673.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:26,534] Trial 4 finished with value: 0.3933920220334528 and parameters: {'max_bin': 367, 'num_leaves': 87, 'lambda_l1': 1.4760742495197955e-08, 'lambda_l2': 0.003620090882797527, 'feature_fraction': 0.7672574336334528, 'bagging_fraction': 0.7701603981248542, 'bagging_freq': 95, 'min_child_samples': 70}. Best is trial 0 with value: 0.38348145448218673.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:26,601] Trial 5 finished with value: 0.39994587599284037 and parameters: {'max_bin': 343, 'num_leaves': 74, 'lambda_l1': 0.0189968136862103, 'lambda_l2': 3.483607722774873e-08, 'feature_fraction': 0.8000600292674006, 'bagging_fraction': 0.8023827217708956, 'bagging_freq': 22, 'min_child_samples': 17}. Best is trial 0 with value: 0.38348145448218673.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.504584	valid_1's multi_logloss: 0.518332
# [20]	training's multi_logloss: 0.442463	valid_1's multi_logloss: 0.460001
# [30]	training's multi_logloss: 0.397771	valid_1's multi_logloss: 0.421388
# [40]	training's multi_logloss: 0.375836	valid_1's multi_logloss: 0.402632
# [50]	training's multi_logloss: 0.35957	valid_1's multi_logloss: 0.393559
# [60]	training's multi_logloss: 0.347835	valid_1's multi_logloss: 0.390178
# [70]	training's multi_logloss: 0.339402	valid_1's multi_logloss: 0.389021
# [80]	training's multi_logloss: 0.3325	valid_1's multi_logloss: 0.389238
# Early stopping, best iteration is:
# [72]	training's multi_logloss: 0.338262	valid_1's multi_logloss: 0.388452
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.469811	valid_1's multi_logloss: 0.489096
# [20]	training's multi_logloss: 0.394762	valid_1's multi_logloss: 0.429424
# [30]	training's multi_logloss: 0.359303	valid_1's multi_logloss: 0.404334
# [40]	training's multi_logloss: 0.337613	valid_1's multi_logloss: 0.395335
# [50]	training's multi_logloss: 0.320942	valid_1's multi_logloss: 0.393951
# [60]	training's multi_logloss: 0.307648	valid_1's multi_logloss: 0.394785
# Early stopping, best iteration is:
# [55]	training's multi_logloss: 0.313379	valid_1's multi_logloss: 0.393392
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.428906	valid_1's multi_logloss: 0.488059
# [20]	training's multi_logloss: 0.331337	valid_1's multi_logloss: 0.427765
# [30]	training's multi_logloss: 0.276069	valid_1's multi_logloss: 0.404515
# [40]	training's multi_logloss: 0.241258	valid_1's multi_logloss: 0.40096
# Early stopping, best iteration is:
# [37]	training's multi_logloss: 0.251637	valid_1's multi_logloss: 0.399946
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.4385	valid_1's multi_logloss: 0.474091
# [20]	training's multi_logloss: 0.36375	valid_1's multi_logloss: 0.423859
# [30]	training's multi_logloss: 0.322361	valid_1's multi_logloss: 0.40255
# [40]	training's multi_logloss: 0.302632	valid_1's multi_logloss: 0.398306
# [I 2023-06-19 21:52:26,651] Trial 6 finished with value: 0.3975941467716012 and parameters: {'max_bin': 332, 'num_leaves': 67, 'lambda_l1': 0.0013544748136111338, 'lambda_l2': 8.859589936506331e-05, 'feature_fraction': 0.9930243028355357, 'bagging_fraction': 0.4612268864488169, 'bagging_freq': 21, 'min_child_samples': 20}. Best is trial 0 with value: 0.38348145448218673.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:26,739] Trial 7 finished with value: 0.39866967328122993 and parameters: {'max_bin': 415, 'num_leaves': 56, 'lambda_l1': 0.00015732471573476155, 'lambda_l2': 1.5842741206950525e-06, 'feature_fraction': 0.49538175018731184, 'bagging_fraction': 0.4662250846985831, 'bagging_freq': 66, 'min_child_samples': 18}. Best is trial 0 with value: 0.38348145448218673.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:26,784] Trial 8 finished with value: 0.4021875587704714 and parameters: {'max_bin': 303, 'num_leaves': 67, 'lambda_l1': 0.2448719663204702, 'lambda_l2': 7.480170242098733e-08, 'feature_fraction': 0.9027669444992823, 'bagging_fraction': 0.45765904473637786, 'bagging_freq': 98, 'min_child_samples': 49}. Best is trial 0 with value: 0.38348145448218673.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# Early stopping, best iteration is:
# [38]	training's multi_logloss: 0.306097	valid_1's multi_logloss: 0.397594
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.50311	valid_1's multi_logloss: 0.527776
# [20]	training's multi_logloss: 0.419132	valid_1's multi_logloss: 0.46383
# [30]	training's multi_logloss: 0.375684	valid_1's multi_logloss: 0.43482
# [40]	training's multi_logloss: 0.34155	valid_1's multi_logloss: 0.416881
# [50]	training's multi_logloss: 0.322887	valid_1's multi_logloss: 0.414437
# [60]	training's multi_logloss: 0.305851	valid_1's multi_logloss: 0.410558
# [70]	training's multi_logloss: 0.287607	valid_1's multi_logloss: 0.405564
# [80]	training's multi_logloss: 0.270778	valid_1's multi_logloss: 0.3997
# [90]	training's multi_logloss: 0.258952	valid_1's multi_logloss: 0.398797
# Early stopping, best iteration is:
# [81]	training's multi_logloss: 0.269076	valid_1's multi_logloss: 0.39867
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.480341	valid_1's multi_logloss: 0.502923
# [20]	training's multi_logloss: 0.409146	valid_1's multi_logloss: 0.445735
# [30]	training's multi_logloss: 0.374502	valid_1's multi_logloss: 0.422107
# [40]	training's multi_logloss: 0.353163	valid_1's multi_logloss: 0.411099
# [50]	training's multi_logloss: 0.339232	valid_1's multi_logloss: 0.406083
# [60]	training's multi_logloss: 0.329394	valid_1's multi_logloss: 0.403543
# [70]	training's multi_logloss: 0.322067	valid_1's multi_logloss: 0.403318
# Early stopping, best iteration is:
# [63]	training's multi_logloss: 0.32675	valid_1's multi_logloss: 0.402188
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.501936	valid_1's multi_logloss: 0.526976
# [20]	training's multi_logloss: 0.416729	valid_1's multi_logloss: 0.464382
# [30]	training's multi_logloss: 0.371435	valid_1's multi_logloss: 0.435205
# [40]	training's multi_logloss: 0.331671	valid_1's multi_logloss: 0.412735
# [I 2023-06-19 21:52:26,854] Trial 9 finished with value: 0.4060396526877144 and parameters: {'max_bin': 495, 'num_leaves': 90, 'lambda_l1': 0.0450165506544907, 'lambda_l2': 2.2526313830315164e-08, 'feature_fraction': 0.5696841775458458, 'bagging_fraction': 0.47211793672790137, 'bagging_freq': 30, 'min_child_samples': 16}. Best is trial 0 with value: 0.38348145448218673.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:26,920] Trial 10 finished with value: 0.4040842434244033 and parameters: {'max_bin': 333, 'num_leaves': 72, 'lambda_l1': 3.778569956294474e-08, 'lambda_l2': 0.017070611332063324, 'feature_fraction': 0.739960872523945, 'bagging_fraction': 0.5592336945636672, 'bagging_freq': 53, 'min_child_samples': 14}. Best is trial 0 with value: 0.38348145448218673.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:27,008] Trial 11 finished with value: 0.391193903136401 and parameters: {'max_bin': 396, 'num_leaves': 122, 'lambda_l1': 7.3641151715586195e-06, 'lambda_l2': 0.010155315483402488, 'feature_fraction': 0.4790787174426353, 'bagging_fraction': 0.8297963224711393, 'bagging_freq': 29, 'min_child_samples': 22}. Best is trial 0 with value: 0.38348145448218673.
# [50]	training's multi_logloss: 0.312218	valid_1's multi_logloss: 0.410101
# [60]	training's multi_logloss: 0.295467	valid_1's multi_logloss: 0.406382
# Early stopping, best iteration is:
# [59]	training's multi_logloss: 0.296261	valid_1's multi_logloss: 0.40604
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.455972	valid_1's multi_logloss: 0.500421
# [20]	training's multi_logloss: 0.373574	valid_1's multi_logloss: 0.444511
# [30]	training's multi_logloss: 0.316615	valid_1's multi_logloss: 0.413614
# [40]	training's multi_logloss: 0.284589	valid_1's multi_logloss: 0.406595
# [50]	training's multi_logloss: 0.261551	valid_1's multi_logloss: 0.407464
# Early stopping, best iteration is:
# [45]	training's multi_logloss: 0.271568	valid_1's multi_logloss: 0.404084
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.490131	valid_1's multi_logloss: 0.521045
# [20]	training's multi_logloss: 0.397328	valid_1's multi_logloss: 0.452501
# [30]	training's multi_logloss: 0.343786	valid_1's multi_logloss: 0.423043
# [40]	training's multi_logloss: 0.304718	valid_1's multi_logloss: 0.404117
# [50]	training's multi_logloss: 0.277773	valid_1's multi_logloss: 0.399083
# [60]	training's multi_logloss: 0.255698	valid_1's multi_logloss: 0.39229
# [70]	training's multi_logloss: 0.237443	valid_1's multi_logloss: 0.393924
# Early stopping, best iteration is:
# [63]	training's multi_logloss: 0.249842	valid_1's multi_logloss: 0.391194
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:27,077] Trial 12 finished with value: 0.38641960894696153 and parameters: {'max_bin': 399, 'num_leaves': 33, 'lambda_l1': 0.2887089604396595, 'lambda_l2': 1.1021971551176847e-08, 'feature_fraction': 0.8066899220777382, 'bagging_fraction': 0.562004783915299, 'bagging_freq': 74, 'min_child_samples': 97}. Best is trial 0 with value: 0.38348145448218673.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
# ...
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:28,654] Trial 36 finished with value: 0.4125280318888207 and parameters: {'max_bin': 377, 'num_leaves': 94, 'lambda_l1': 2.0761630387185133e-05, 'lambda_l2': 1.7064848820677366e-07, 'feature_fraction': 0.8932706399165473, 'bagging_fraction': 0.5139087471416548, 'bagging_freq': 52, 'min_child_samples': 26}. Best is trial 33 with value: 0.3756202124969309.
# [90]	training's multi_logloss: 0.33346	valid_1's multi_logloss: 0.383397
# [100]	training's multi_logloss: 0.326404	valid_1's multi_logloss: 0.381218
# [110]	training's multi_logloss: 0.319815	valid_1's multi_logloss: 0.379365
# [120]	training's multi_logloss: 0.313829	valid_1's multi_logloss: 0.37766
# [130]	training's multi_logloss: 0.308214	valid_1's multi_logloss: 0.376721
# [140]	training's multi_logloss: 0.303737	valid_1's multi_logloss: 0.375693
# [150]	training's multi_logloss: 0.299892	valid_1's multi_logloss: 0.376115
# Early stopping, best iteration is:
# [143]	training's multi_logloss: 0.302327	valid_1's multi_logloss: 0.37562
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.463951	valid_1's multi_logloss: 0.482063
# [20]	training's multi_logloss: 0.399772	valid_1's multi_logloss: 0.427731
# [30]	training's multi_logloss: 0.369063	valid_1's multi_logloss: 0.405843
# [40]	training's multi_logloss: 0.350475	valid_1's multi_logloss: 0.395573
# [50]	training's multi_logloss: 0.333566	valid_1's multi_logloss: 0.389767
# [60]	training's multi_logloss: 0.321087	valid_1's multi_logloss: 0.388992
# [70]	training's multi_logloss: 0.310625	valid_1's multi_logloss: 0.386371
# [80]	training's multi_logloss: 0.30265	valid_1's multi_logloss: 0.386023
# Early stopping, best iteration is:
# [76]	training's multi_logloss: 0.305573	valid_1's multi_logloss: 0.385506
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.489921	valid_1's multi_logloss: 0.513301
# [20]	training's multi_logloss: 0.425976	valid_1's multi_logloss: 0.45741
# [30]	training's multi_logloss: 0.380089	valid_1's multi_logloss: 0.421106
# [40]	training's multi_logloss: 0.356579	valid_1's multi_logloss: 0.408348
# [50]	training's multi_logloss: 0.341919	valid_1's multi_logloss: 0.407117
# [60]	training's multi_logloss: 0.330894	valid_1's multi_logloss: 0.406525
# [70]	training's multi_logloss: 0.322711	valid_1's multi_logloss: 0.40567
# [80]	training's multi_logloss: 0.316305	valid_1's multi_logloss: 0.40563
# Early stopping, best iteration is:
# [76]	training's multi_logloss: 0.318769	valid_1's multi_logloss: 0.404725
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.460386	valid_1's multi_logloss: 0.495754
# [20]	training's multi_logloss: 0.379021	valid_1's multi_logloss: 0.437218
# [30]	training's multi_logloss: 0.338237	valid_1's multi_logloss: 0.417879
# [40]	training's multi_logloss: 0.313465	valid_1's multi_logloss: 0.413231
# [50]	training's multi_logloss: 0.296719	valid_1's multi_logloss: 0.415559
# Early stopping, best iteration is:
# [43]	training's multi_logloss: 0.307369	valid_1's multi_logloss: 0.412528
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:28,742] Trial 37 finished with value: 0.39651958778495505 and parameters: {'max_bin': 279, 'num_leaves': 115, 'lambda_l1': 5.70525947903341, 'lambda_l2': 4.441318538278994, 'feature_fraction': 0.9439332995327073, 'bagging_fraction': 0.8644283996191833, 'bagging_freq': 34, 'min_child_samples': 12}. Best is trial 33 with value: 0.3756202124969309.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:28,802] Trial 38 finished with value: 0.4142498605142833 and parameters: {'max_bin': 355, 'num_leaves': 54, 'lambda_l1': 1.5573589132823735e-07, 'lambda_l2': 3.025830777863833e-08, 'feature_fraction': 0.8353566185263472, 'bagging_fraction': 0.40685647517501866, 'bagging_freq': 78, 'min_child_samples': 19}. Best is trial 33 with value: 0.3756202124969309.
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:20: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Local\Temp\ipykernel_1572\3341545109.py:21: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [I 2023-06-19 21:52:28,857] Trial 39 finished with value: 0.3902506166174407 and parameters: {'max_bin': 274, 'num_leaves': 40, 'lambda_l1': 0.011179702998691652, 'lambda_l2': 1.6154922862963978e-06, 'feature_fraction': 0.6523236800080591, 'bagging_fraction': 0.7344212747943502, 'bagging_freq': 87, 'min_child_samples': 74}. Best is trial 33 with value: 0.3756202124969309.
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.472295	valid_1's multi_logloss: 0.498502
# [20]	training's multi_logloss: 0.406429	valid_1's multi_logloss: 0.447621
# [30]	training's multi_logloss: 0.374297	valid_1's multi_logloss: 0.423043
# [40]	training's multi_logloss: 0.356592	valid_1's multi_logloss: 0.410435
# [50]	training's multi_logloss: 0.345717	valid_1's multi_logloss: 0.403504
# [60]	training's multi_logloss: 0.338599	valid_1's multi_logloss: 0.399707
# [70]	training's multi_logloss: 0.333365	valid_1's multi_logloss: 0.397423
# [80]	training's multi_logloss: 0.329347	valid_1's multi_logloss: 0.396557
# [90]	training's multi_logloss: 0.326592	valid_1's multi_logloss: 0.396556
# Early stopping, best iteration is:
# [82]	training's multi_logloss: 0.328705	valid_1's multi_logloss: 0.39652
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.462285	valid_1's multi_logloss: 0.496402
# [20]	training's multi_logloss: 0.382041	valid_1's multi_logloss: 0.436251
# [30]	training's multi_logloss: 0.343057	valid_1's multi_logloss: 0.416902
# [40]	training's multi_logloss: 0.321692	valid_1's multi_logloss: 0.414804
# Early stopping, best iteration is:
# [37]	training's multi_logloss: 0.327766	valid_1's multi_logloss: 0.41425
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.486441	valid_1's multi_logloss: 0.507471
# [20]	training's multi_logloss: 0.421616	valid_1's multi_logloss: 0.450447
# [30]	training's multi_logloss: 0.375548	valid_1's multi_logloss: 0.412253
# [40]	training's multi_logloss: 0.351685	valid_1's multi_logloss: 0.399545
# [50]	training's multi_logloss: 0.335985	valid_1's multi_logloss: 0.393122
# [60]	training's multi_logloss: 0.323565	valid_1's multi_logloss: 0.391606
# [70]	training's multi_logloss: 0.313467	valid_1's multi_logloss: 0.3909
# [80]	training's multi_logloss: 0.305378	valid_1's multi_logloss: 0.391086
# Early stopping, best iteration is:
# [72]	training's multi_logloss: 0.311735	valid_1's multi_logloss: 0.390251

# %%
study.best_params
# Out:
# {'max_bin': 419,
#  'num_leaves': 108,
#  'lambda_l1': 3.432187077228294e-06,
#  'lambda_l2': 0.0018953590604522356,
#  'feature_fraction': 0.4383731596725887,
#  'bagging_fraction': 0.6913765575607738,
#  'bagging_freq': 98,
#  'min_child_samples': 89}

# %%
params = {
    'objective': 'multiclass',
    'verbose': -1,
    'num_class': 3,
    'max_bin' : study.best_params['max_bin'],
    'learning_rate' : 0.05,
    'num_leaves' : study.best_params['num_leaves'],
    'metric' : 'multi_logloss',
    'lambda_l1': study.best_params['lambda_l1'],
    'lambda_l2': study.best_params['lambda_l2'],
    'feature_fraction': study.best_params['feature_fraction'],
    'bagging_fraction': study.best_params['bagging_fraction'],
    'bagging_freq': study.best_params['bagging_freq'],
    'min_child_samples': study.best_params['min_child_samples']
}

lgb_train = lgb.Dataset(X_train, y_train, categorical_feature=categorical_features)
lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train, categorical_feature=categorical_features)

model = lgb.train(params,lgb_train,
                  valid_sets=[lgb_train, lgb_eval],
                  verbose_eval=10,
                  num_boost_round=1000,
                  early_stopping_rounds=10)
y_pred = model.predict(X_test, num_iteration=model.best_iteration)
# Out:
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.53889	valid_1's multi_logloss: 0.542051
# [20]	training's multi_logloss: 0.464411	valid_1's multi_logloss: 0.473401
# [30]	training's multi_logloss: 0.424115	valid_1's multi_logloss: 0.439256
# [40]	training's multi_logloss: 0.396632	valid_1's multi_logloss: 0.416869
# [50]	training's multi_logloss: 0.378813	valid_1's multi_logloss: 0.4062
# [60]	training's multi_logloss: 0.362579	valid_1's multi_logloss: 0.39522
# [70]	training's multi_logloss: 0.351304	valid_1's multi_logloss: 0.390167
# [80]	training's multi_logloss: 0.342395	valid_1's multi_logloss: 0.387488
# [90]	training's multi_logloss: 0.33346	valid_1's multi_logloss: 0.383397
# [100]	training's multi_logloss: 0.326404	valid_1's multi_logloss: 0.381218
# [110]	training's multi_logloss: 0.319815	valid_1's multi_logloss: 0.379365
# [120]	training's multi_logloss: 0.313829	valid_1's multi_logloss: 0.37766
# [130]	training's multi_logloss: 0.308214	valid_1's multi_logloss: 0.376721
# [140]	training's multi_logloss: 0.303737	valid_1's multi_logloss: 0.375693
# [150]	training's multi_logloss: 0.299892	valid_1's multi_logloss: 0.376115
# Early stopping, best iteration is:
# [143]	training's multi_logloss: 0.302327	valid_1's multi_logloss: 0.37562
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\kabeo\AppData\Roaming\Python\Python310\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')

# %%
y_pred.shape
# Out:
# (400, 3)

# %%
y_pred_max = np.argmax(y_pred, axis=1)

# %%
sample_submit = pd.read_csv("sample_submit.csv",header=None, names=['id','charges'])

# %%
sample_submit['charges'] = y_pred_max

# %%
pd.DataFrame(sample_submit).to_csv('hold-outOptuna3_.csv', index=False, header=False)
